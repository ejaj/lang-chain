# %%
from dotenv import load_dotenv
from langchain.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model="gpt-4o")

# %%
template = "Tell me a joke about {topic}"
prompt_template = ChatPromptTemplate.from_template(template)
prompt = prompt_template.invoke({"topic": "cats"})
result = model.invoke(prompt)
print(result.content)
# Out:
# Why was the cat sitting on the computer?
#
# Because it wanted to keep an eye on the mouse!

# %%
template_multiple = """You are a helpful assistant.
Human: Tell me a {adjective} short story about a {animal}.
Assistant:"""
prompt_multiple = ChatPromptTemplate.from_template(template_multiple)
prompt = prompt_multiple.invoke({"adjective": "funny", "animal": "panda"})
result = model.invoke(prompt)
print(result.content)
# Out:
# Once upon a time in a bamboo forest, there lived a panda named Pudding. Pudding had a peculiar talent for getting into hilarious predicaments. One sunny morning, as Pudding was lounging in his favorite tree, he noticed a colorful butterfly fluttering by. Curious, he decided to follow it.
#
# The butterfly led Pudding on a merry chase through the forest. He stumbled over logs, tripped on rocks, and even tumbled head over paws down a hill, but he never lost sight of the butterfly. Finally, the butterfly landed on a small, unassuming patch of bamboo shoots.
#
# Exhausted but triumphant, Pudding reached the spot and discovered that the bamboo shoots were the juiciest and most delicious he had ever tasted! As he munched happily, he realized that sometimes, a little adventure leads to the best snacks.
#
# From that day on, Pudding became known as the panda who followed the butterflies, always on the lookout for his next delicious surprise. And every panda in the forest agreed, Pudding's escapades were as delightful as they were funny.

# %%
messages = [
    ("system", "You are a comedian who tells jokes about {topic}."),
    ("human", "Tell me {joke_count} jokes."),
]
prompt_template = ChatPromptTemplate.from_messages(messages)
prompt = prompt_template.invoke({"topic": "lawyers", "joke_count": 3})
result = model.invoke(prompt)
print(result.content)
# Out:
# Sure, here are three lawyer jokes for you:
#
# 1. Why don't sharks attack lawyers?
#    Professional courtesy.
#
# 2. What's the difference between a lawyer and a herd of buffalo?
#    The lawyer charges more.
#
# 3. What's the difference between a lawyer and a vulture?
#    Lawyers accumulate frequent flyer miles.
