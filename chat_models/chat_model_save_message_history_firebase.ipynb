# %%
from dotenv import load_dotenv
from google.cloud import firestore
from langchain_google_firestore import FirestoreChatMessageHistory
from langchain_openai import ChatOpenAI

# %%
load_dotenv()
# Out:
# True

# %%
PROJECT_ID = "myproject-fe415"
SESSION_ID = "user_session_new"  # This could be a username or a unique ID
COLLECTION_NAME = "chat_history"

# %%
# Initialize Firestore Client
print("Initializing Firestore Client...")
client = firestore.Client(project=PROJECT_ID)
# Out:
# Initializing Firestore Client...

# %%
# Initialize Firestore Chat Message History
print("Initializing Firestore Chat Message History...")
chat_history = FirestoreChatMessageHistory(
    session_id=SESSION_ID,
    collection=COLLECTION_NAME,
    client=client,
)
print("Chat History Initialized.")
print("Current Chat History:", chat_history.messages)

# Initialize Chat Model
model = ChatOpenAI()

print("Start chatting with the AI. Type 'exit' to quit.")

while True:
    human_input = input("User: ")
    if human_input.lower() == "exit":
        break

    chat_history.add_user_message(human_input)

    ai_response = model.invoke(chat_history.messages)
    chat_history.add_ai_message(ai_response.content)

    print(f"AI: {ai_response.content}")
# Out:
# Initializing Firestore Chat Message History...
# Chat History Initialized.
# Current Chat History: []
# Start chatting with the AI. Type 'exit' to quit.
# AI: Firebase is a mobile and web application development platform that provides a variety of tools and services for developers to build, improve, and grow their apps. It is developed by Google and offers features such as real-time database, authentication, cloud messaging, analytics, and hosting.
#
# Firebase's real-time database allows developers to store and sync data in real-time across all clients. This makes it easy to build apps that require real-time updates and collaboration.
#
# Firebase Authentication provides easy-to-use authentication methods, such as email/password, phone number, and social media logins, to verify users and secure access to the app.
#
# Firebase Cloud Messaging enables developers to send notifications and messages to users across platforms, helping to engage and retain users.
#
# Firebase Analytics provides insights into user behavior, app performance, and marketing campaigns, allowing developers to make data-driven decisions to improve their app.
#
# Firebase Hosting allows developers to deploy web apps quickly and securely on Google's infrastructure, ensuring high performance and reliability.
#
# Overall, Firebase is a powerful platform that simplifies app development, improves user engagement, and helps developers grow their apps effectively.
