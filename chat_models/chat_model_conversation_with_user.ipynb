# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain.schema import AIMessage, HumanMessage, SystemMessage

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model="gpt-4o")

# %%
chat_history = []
# Set an initial system message (optional)
system_message = SystemMessage(content="You are a helpful AI assistant.")
chat_history.append(system_message)  # Add system message to chat history

# %%
while True:
    query = input("You: ")
    if query.lower() == "exit":
        break
    chat_history.append(HumanMessage(content=query))  # Add user message

    result = model.invoke(chat_history)
    response = result.content
    chat_history.append(AIMessage(content=response))  # Add AI message
    print(f"AI: {response}")
# Out:
# AI: I am an AI assistant designed to help answer questions and provide information on a wide range of topics. If you have anything specific you'd like to know or need assistance with, feel free to ask!
# AI: It seems like your question might be incomplete. Could you please provide more details or clarify what you would like to know? I'm here to help with any information or questions you might have!

# %%
print("---- Message History ----")
print(chat_history)
# Out:
# ---- Message History ----
# [SystemMessage(content='You are a helpful AI assistant.'), HumanMessage(content='Who are you'), AIMessage(content="I am an AI assistant designed to help answer questions and provide information on a wide range of topics. If you have anything specific you'd like to know or need assistance with, feel free to ask!"), HumanMessage(content='How to konw??'), AIMessage(content="It seems like your question might be incomplete. Could you please provide more details or clarify what you would like to know? I'm here to help with any information or questions you might have!")]
